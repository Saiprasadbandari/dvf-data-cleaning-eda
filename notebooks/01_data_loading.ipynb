# %%
import pandas as pd
import numpy as np
from pathlib import Path

RAW_DIR = Path("../data/raw")

files = sorted(RAW_DIR.glob("*.txt.zip"))
files
# Out:
# [PosixPath('../data/raw/valeursfoncieres-2021.txt.zip'),
#  PosixPath('../data/raw/valeursfoncieres-2022.txt.zip'),
#  PosixPath('../data/raw/valeursfoncieres-2023.txt.zip'),
#  PosixPath('../data/raw/valeursfoncieres-2024.txt.zip'),
#  PosixPath('../data/raw/valeursfoncieres-2025.txt.zip')]

# %%
dfs = []

for file in files:
    print("Loading:", file.name)
    temp_df = pd.read_csv(file, sep="|", low_memory=False)
    temp_df["source_file"] = file.name
    dfs.append(temp_df)

df = pd.concat(dfs, ignore_index=True)

print("Final shape:", df.shape)
df.head()
# Out:
# Loading: valeursfoncieres-2021.txt.zip
# Loading: valeursfoncieres-2022.txt.zip
# Loading: valeursfoncieres-2023.txt.zip
# Loading: valeursfoncieres-2024.txt.zip
# Loading: valeursfoncieres-2025.txt.zip
# Final shape: (20382915, 44)
#    Identifiant de document  Reference document  1 Articles CGI  \
# 0                      NaN                 NaN             NaN
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    No disposition Date mutation Nature mutation  ... Nombre de lots  \
# 0               1    05/01/2021           Vente  ...              0
# 1               1    05/01/2021           Vente  ...              0
# 2               1    06/01/2021           Vente  ...              0
# 3               1    04/01/2021           Vente  ...              0
# 4               1    06/01/2021           Vente  ...              0
#
#    Code type local  Type local Identifiant local Surface reelle bati  \
# 0              3.0  Dépendance               NaN                 0.0
# 1              1.0      Maison               NaN                97.0
# 2              NaN         NaN               NaN                 NaN
# 3              1.0      Maison               NaN                88.0
# 4              3.0  Dépendance               NaN                 0.0
#
#   Nombre pieces principales  Nature culture Nature culture speciale  \
# 0                       0.0               S                     NaN
# 1                       5.0               S                     NaN
# 2                       NaN              BT                     NaN
# 3                       4.0               S                     NaN
# 4                       0.0               S                     NaN
#
#   Surface terrain                    source_file
# 0          2410.0  valeursfoncieres-2021.txt.zip
# 1          2410.0  valeursfoncieres-2021.txt.zip
# 2           530.0  valeursfoncieres-2021.txt.zip
# 3           866.0  valeursfoncieres-2021.txt.zip
# 4          1426.0  valeursfoncieres-2021.txt.zip
#
# [5 rows x 44 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20382915 entries, 0 to 20382914
# Data columns (total 44 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Identifiant de document     float64
#  1   Reference document          float64
#  2   1 Articles CGI              float64
#  3   2 Articles CGI              float64
#  4   3 Articles CGI              float64
#  5   4 Articles CGI              float64
#  6   5 Articles CGI              float64
#  7   No disposition              int64
#  8   Date mutation               object
#  9   Nature mutation             object
#  10  Valeur fonciere             object
#  11  No voie                     float64
#  12  B/T/Q                       object
#  13  Type de voie                object
#  14  Code voie                   object
#  15  Voie                        object
#  16  Code postal                 float64
#  17  Commune                     object
#  18  Code departement            object
#  19  Code commune                int64
#  20  Prefixe de section          float64
#  21  Section                     object
#  22  No plan                     int64
#  23  No Volume                   object
#  24  1er lot                     object
#  25  Surface Carrez du 1er lot   object
#  26  2eme lot                    object
#  27  Surface Carrez du 2eme lot  object
#  28  3eme lot                    object
#  29  Surface Carrez du 3eme lot  object
#  30  4eme lot                    object
#  31  Surface Carrez du 4eme lot  object
#  32  5eme lot                    object
#  33  Surface Carrez du 5eme lot  object
#  34  Nombre de lots              int64
#  35  Code type local             float64
#  36  Type local                  object
#  37  Identifiant local           float64
#  38  Surface reelle bati         float64
#  39  Nombre pieces principales   float64
#  40  Nature culture              object
#  41  Nature culture speciale     object
#  42  Surface terrain             float64
#  43  source_file                 object
# dtypes: float64(15), int64(4), object(25)
# memory usage: 6.7+ GB
